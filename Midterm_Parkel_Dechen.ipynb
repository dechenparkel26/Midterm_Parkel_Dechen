# %%
#Convert txt file into a readable list in Python while importing all necessary libraries.
import re
import pandas as pd
import json
import matplotlib.pyplot as plt
import numpy as np


numdata=open("C:/Users/deche/OneDrive - The George Washington University/Freshman Year/Spring 2023/Intro to Computing/Mid-term Project (1)/Mid-term Project/numbers.txt", "r")
numstring=numdata.read()
numlist=re.split(r',|\n', numstring)
print(numlist)
# Out:
# ['2', '4', '6', '8', '4', '5', '2', '1', '9', '0', '4', '6', '7', '4', '3', '2', '1', '9', '10', '3', '7', '9', '6', '0', '1', '3', '5', '6', '7', '8', '9', '10', '2', '3', '6', '8', '9', '10', '6', '7', '4', '3', '2', '1', '9', '10', '3', '7', '9', '6', '0', '1', '3', '5', '6', '7', '8', '9', '10', '2', '3', '6', '8', '9', '10', '2', '4', '6', '8', '4', '5', '2', '1', '9', '0', '4', '6', '7', '4', '3', '2', '1', '9', '10', '3', '7', '9', '6', '4', '5', '2', '1', '9', '0', '4', '6', '7', '4', '3', '2', '1', '9', '10', '3', '7', '9', '6', '0', '1', '3', '5', '6', '7', '8', '9', '10', '2', '3', '6', '8', '9', '10', '6', '7', '4', '3', '6', '8', '4', '5', '2', '10', '3', '7', '9', '6', '0', '1', '3', '5', '6', '7', '8', '9', '10', '2', '3', '6', '8', '9', '10', '2', '4', '6', '8', '4', '5', '2', '1', '9', '0', '4', '6', '7', '4', '2', '4', '6', '8', '4', '5', '2', '1', '9', '0', '4', '6', '7', '4', '3', '2', '1', '9', '10', '3', '7', '9', '6']

# %%
#Converted list into a dictionary so i could count frequency
d = {}
for item in numlist:
    if item not in d.keys():
        d[item]=1
    else:
        d[item]+=1
d
# Out:
# {'2': 19,
#  '4': 22,
#  '6': 26,
#  '8': 13,
#  '5': 10,
#  '1': 14,
#  '9': 24,
#  '0': 9,
#  '7': 17,
#  '3': 20,
#  '10': 14}

# %%
#Here I uploaded the file to foler as a json file
path = r"C:/Users/deche/OneDrive - The George Washington University/Freshman Year/Spring 2023/Intro to Computing/Mid-term Project (1)/Mid-term Project/out.json"
with open(path, "w") as out:
    json.dump(d,out)
f=open("C:/Users/deche/OneDrive - The George Washington University/Freshman Year/Spring 2023/Intro to Computing/Mid-term Project (1)/Mid-term Project/out.json","r")
f
# Out:
# <_io.TextIOWrapper name='C:/Users/deche/OneDrive - The George Washington University/Freshman Year/Spring 2023/Intro to Computing/Mid-term Project (1)/Mid-term Project/out.json' mode='r' encoding='cp1252'>

# %%
df=pd.read_csv("C:/Users/deche/OneDrive - The George Washington University/Freshman Year/Spring 2023/Intro to Computing/Mid-term Project (1)/Mid-term Project/The Good Stuff Stats - Sheet13.csv")
df
# Out:
#                                       Song Title Length  Length (seconds)  \
# 0                                 If I Can Dream   3:13               193
# 1                                    The Promise   3:43               223
# 2                        Your Time is Gonna Come   4:35               275
# 3                          And Then He Kissed me   2:35               155
# 4                     Working my Way Back to You   4:03               243
# 5                                River of Dreams   4:07               247
# 6   [Your Love Keeps Lifting me] Higher & Higher   3:02               182
# 7                               In The Year 2525   3:20               200
# 8                                    Any Day Now   3:03               183
# 9                                     Holy Diver   5:55               355
# 10                                 In the Ghetto   2:59               179
# 11                       [What A] Wonderul World   2:10               130
# 12                   I Want to Know What Love Is   5:05               305
# 13                               Everybody Hurts   5:21               321
# 14                                     Barcelona   4:25               265
# 15                                      Sussudio   4:27               267
# 16                          You Can't Hurry Love   2:53               173
# 17                                  Baba O'Riley   5:07               307
# 18                      Only You (and you alone)   2:37               167
# 19                               Golden Slumbers   1:32                92
# 20                     In the Still of the Night   3:08               188
# 21                        Ain't too Proud to Beg   2:34               154
# 22              The Way You Do The Things You Do   2:46               166
# 23                              Blue Suede Shoes   2:03               123
# 24                    Can't Help Falling In Love   3:01               181
# 25                                     Black Dog   4:56               296
# 26                                  Burning Love   2:58               178
# 27                 I'll Never Fall In Love Again   4:00               240
# 28                               Love Me Tonight   3:11               191
#
#     Year Released Decade Released             Genre Artist's Country  \
# 0            1968          1960's               R&B              USA
# 1            1988          1980's          Pop Rock          England
# 2            1969          1960's  Alternative Rock          England
# 3            1963          1960's       Rock n Roll              USA
# 4            1975          1970's               R&B              USA
# 5            1993          1990's  Alternative Rock              USA
# 6            1967          1960's               R&B              USA
# 7            1969          1960's      Country Rock              USA
# 8            1962          1960's               R&B              USA
# 9            1983          1980's  Alternative Rock              USA
# 10           1969          1960's               R&B              USA
# 11           1959          1950's               R&B              USA
# 12           1984          1980's         Soft Rock          England
# 13           1992          1990's  Alternative Rock              USA
# 14           1987          1980's        Orchestral          England
# 15           1985          1980's  Alternative Rock          England
# 16           1986          1980's               R&B          England
# 17           1971          1970's  Alternative Rock          England
# 18           1956          1950's               R&B              USA
# 19           1969          1960's  Progressive Rock          England
# 20           1956          1950's           Doo-Wop              USA
# 21           1966          1960's               R&B              USA
# 22           1964          1960's               R&B              USA
# 23           1956          1950's       Rock n Roll              USA
# 24           1961          1960's               R&B              USA
# 25           1971          1970's       Rock n Roll          England
# 26           1972          1970's       Rock n Roll              USA
# 27           1967          1960's               R&B          England
# 28           1969          1960's               R&B          England
#
#     Times Listened
# 0               10
# 1                1
# 2                2
# 3                5
# 4               14
# 5                2
# 6               15
# 7               10
# 8                4
# 9                2
# 10               4
# 11               4
# 12               3
# 13               2
# 14               1
# 15               1
# 16               2
# 17               2
# 18               2
# 19               1
# 20               2
# 21               3
# 22               3
# 23               3
# 24               5
# 25               2
# 26               6
# 27               9
# 28               9

# %%
plt.pie(df["Times Listened"], labels=df["Song Title"])
plt.show()

# %%
df.plot(kind="bar", x="Song Title", y="Times Listened")
# Out:
# <AxesSubplot:xlabel='Song Title'>
